# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel("Lending Data.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
data.head(75)
# Out:
#        Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                              NaN      NaN   -1        -2         -3
# 1            American Express Co.       NY     1   0.23829   0.999544
# 2         First Citizens Banchares      NC     2  0.187393    0.49083
# 3         Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                    Zions Bancorp      UT     4  0.117973   0.260577
# ..                             ...      ...  ...       ...        ...
# 70  Astoria FS & LA                      NY   70  0.009801   0.256392
# 71  Hudson City Svg Bk FSB               NJ   71  0.000986          1
# 72             Svb Financial Grp.       CA    72  0.019486   0.078574
# 73                      UBS Bk USA      UT    73  0.014298   0.138694
# 74                 City Nat Corp.       CA    74  0.021068   0.068085
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
data.shape
# Out:
# (97, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  96 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         94 non-null     object
#  3   TA Ratio1                    94 non-null     object
#  4   TBL Ratio1                   94 non-null     object
#  5   Amount ($1,000)              94 non-null     object
#  6   Number                       94 non-null     object
#  7   Lender Asset Size            94 non-null     object
#  8   Amount ($1,000).1            94 non-null     float64
#  9   Number .1                    94 non-null     float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            94 non-null     float64
#  12  Number .2                    94 non-null     float64
# ...

# %%
data['Name of Lending Institution'].value_counts()
# Out:
# American Express Co.                                                                      1
# First Citizens Banchares                                                                  1
# Hudson City Svg Bk FSB                                                                    1
# Astoria FS & LA                                                                           1
# Scottrade Bk                                                                              1
#                                                                                          ..
# BMO Harris Bank NA                                                                        1
# Bank of The West                                                                          1
# PNC Financial Svc. Group                                                                  1
# Wells Fargo & Co                                                                          1
# ...

# %%
data['HQ State'].value_counts()
# Out:
# NY     10
# CA      8
# IL      5
# PA      4
# TX      4
# OH      4
# MO      3
# UT      3
# NC      3
# DE      3
# NV      2
# CA      2
# NY      2
# NJ      2
# PR      2
# MN      2
# GA      2
# VA      2
# AL      2
# MS      2
# UT      2
# NE      1
# IL      1
# VA      1
# MA      1
# MI      1
# FL      1
# OR      1
# TX      1
# NJ      1
# MO      1
# WA      1
# HI      1
# TN      1
# FL      1
# OK      1
# AR      1
# CO      1
# LA      1
# MI      1
# RI      1
# CT      1
# CT      1
# WI      1
# OH      1
# Name: HQ State, dtype: int64

# %%
sns.countplot(data['CC Amount/TA1'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['Rank'].describe()
# Out:
# count     94
# unique    82
# top       NR
# freq       5
# Name: Rank, dtype: object

# %%
data = data.replace('.',np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  96 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         94 non-null     object
#  3   TA Ratio1                    94 non-null     object
#  4   TBL Ratio1                   94 non-null     object
#  5   Amount ($1,000)              94 non-null     object
#  6   Number                       94 non-null     object
#  7   Lender Asset Size            94 non-null     object
#  8   Amount ($1,000).1            94 non-null     float64
#  9   Number .1                    94 non-null     float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            94 non-null     float64
#  12  Number .2                    94 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# Name of Lending Institution     1
# HQ State                        4
# Rank                            3
# TA Ratio1                       3
# TBL Ratio1                      3
# Amount ($1,000)                 3
# Number                          3
# Lender Asset Size               3
# Amount ($1,000).1               3
# Number .1                       3
# Unnamed: 10                    97
# Amount ($1,000).2               3
# Number .2                       3
# CC Amount/TA1                   3
# dtype: int64

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  0 non-null      object
#  1   HQ State                     0 non-null      object
#  2   Rank                         0 non-null      object
#  3   TA Ratio1                    0 non-null      object
#  4   TBL Ratio1                   0 non-null      object
#  5   Amount ($1,000)              0 non-null      object
#  6   Number                       0 non-null      object
#  7   Lender Asset Size            0 non-null      object
#  8   Amount ($1,000).1            0 non-null      float64
#  9   Number .1                    0 non-null      float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            0 non-null      float64
#  12  Number .2                    0 non-null      float64
# ...

# %%
data['HQ State'].value_counts()
# Out:
# Series([], Name: HQ State, dtype: int64)

# %%
data['HQ State'] = pd.to_numeric(data['HQ State'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  0 non-null      object
#  1   HQ State                     0 non-null      int64
#  2   Rank                         0 non-null      object
#  3   TA Ratio1                    0 non-null      object
#  4   TBL Ratio1                   0 non-null      object
#  5   Amount ($1,000)              0 non-null      object
#  6   Number                       0 non-null      object
#  7   Lender Asset Size            0 non-null      object
#  8   Amount ($1,000).1            0 non-null      float64
#  9   Number .1                    0 non-null      float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            0 non-null      float64
#  12  Number .2                    0 non-null      float64
# ...

# %%
data = data.replace('-',np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  0 non-null      object
#  1   HQ State                     0 non-null      int64
#  2   Rank                         0 non-null      object
#  3   TA Ratio1                    0 non-null      object
#  4   TBL Ratio1                   0 non-null      object
#  5   Amount ($1,000)              0 non-null      object
#  6   Number                       0 non-null      object
#  7   Lender Asset Size            0 non-null      object
#  8   Amount ($1,000).1            0 non-null      float64
#  9   Number .1                    0 non-null      float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            0 non-null      float64
#  12  Number .2                    0 non-null      float64
# ...

# %%
data['Rank'].value_counts()
# Out:
# Series([], Name: Rank, dtype: int64)

# %%
data.isnull().sum()
# Out:
# Name of Lending Institution    0.0
# HQ State                       0.0
# Rank                           0.0
# TA Ratio1                      0.0
# TBL Ratio1                     0.0
# Amount ($1,000)                0.0
# Number                         0.0
# Lender Asset Size              0.0
# Amount ($1,000).1              0.0
# Number .1                      0.0
# Unnamed: 10                    0.0
# Amount ($1,000).2              0.0
# Number .2                      0.0
# CC Amount/TA1                  0.0
# dtype: float64

# %%
data['CC Amount/TA1'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CC Amount/TA1, dtype: float64
